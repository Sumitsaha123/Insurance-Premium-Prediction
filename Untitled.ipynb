# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("insurance.csv")
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>sex</th>
#       <th>bmi</th>
#       <th>children</th>
#       <th>smoker</th>
#       <th>region</th>
#       <th>charges</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>19</td>
#       <td>female</td>
#       <td>27.900</td>
#       <td>0</td>
#       <td>yes</td>
#       <td>southwest</td>
#       <td>16884.92400</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>18</td>
#       <td>male</td>
#       <td>33.770</td>
#       <td>1</td>
#       <td>no</td>
#       <td>southeast</td>
#       <td>1725.55230</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>28</td>
#       <td>male</td>
#       <td>33.000</td>
#       <td>3</td>
#       <td>no</td>
#       <td>southeast</td>
#       <td>4449.46200</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>33</td>
#       <td>male</td>
#       <td>22.705</td>
#       <td>0</td>
#       <td>no</td>
#       <td>northwest</td>
#       <td>21984.47061</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>32</td>
#       <td>male</td>
#       <td>28.880</td>
#       <td>0</td>
#       <td>no</td>
#       <td>northwest</td>
#       <td>3866.85520</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.shape
# Out:
# (1338, 7)

# %%
#Checking missing or Null values (If any)
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
sns.pairplot(df,diag_kind="kde")

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(221)
x = df["age"]
y = df["charges"]
ax.scatter(x,y)
plt.xlabel("Ages")
plt.ylabel("Charges")

ax = fig.add_subplot(222)
x1 = df["bmi"]
x2 = df["smoker"]
ax.scatter(x1,y)
plt.xlabel("BMI")

ax = fig.add_subplot(223)
ax.scatter(x2,y)
plt.xlabel("Smoker")
plt.ylabel("Charges")
plt.show()

# %%
unique_dict = {'Sex':df['sex'].unique(),'Children':df['children'].unique(),'Smoker':df['smoker'].unique(),
               'Region': df['region'].unique()}
unique_dict
# Out:
# {'Sex': array(['female', 'male'], dtype=object),
#  'Children': array([0, 1, 3, 2, 5, 4], dtype=int64),
#  'Smoker': array(['yes', 'no'], dtype=object),
#  'Region': array(['southwest', 'southeast', 'northwest', 'northeast'], dtype=object)}

# %%
df = pd.get_dummies(df,drop_first=True)
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>bmi</th>
#       <th>children</th>
#       <th>charges</th>
#       <th>sex_male</th>
#       <th>smoker_yes</th>
#       <th>region_northwest</th>
#       <th>region_southeast</th>
#       <th>region_southwest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>19</td>
#       <td>27.900</td>
#       <td>0</td>
#       <td>16884.92400</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>18</td>
#       <td>33.770</td>
#       <td>1</td>
#       <td>1725.55230</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>28</td>
#       <td>33.000</td>
#       <td>3</td>
#       <td>4449.46200</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>33</td>
#       <td>22.705</td>
#       <td>0</td>
#       <td>21984.47061</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>32</td>
#       <td>28.880</td>
#       <td>0</td>
#       <td>3866.85520</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.corr()
# Out:
#                        age       bmi  children   charges  sex_male  \
# age               1.000000  0.109272  0.042469  0.299008 -0.020856
# bmi               0.109272  1.000000  0.012759  0.198341  0.046371
# children          0.042469  0.012759  1.000000  0.067998  0.017163
# charges           0.299008  0.198341  0.067998  1.000000  0.057292
# sex_male         -0.020856  0.046371  0.017163  0.057292  1.000000
# smoker_yes       -0.025019  0.003750  0.007673  0.787251  0.076185
# region_northwest -0.000407 -0.135996  0.024806 -0.039905 -0.011156
# region_southeast -0.011642  0.270025 -0.023066  0.073982  0.017117
# region_southwest  0.010016 -0.006205  0.021914 -0.043210 -0.004184
#
#                   smoker_yes  region_northwest  region_southeast  \
# age                -0.025019         -0.000407         -0.011642
# bmi                 0.003750         -0.135996          0.270025
# children            0.007673          0.024806         -0.023066
# charges             0.787251         -0.039905          0.073982
# sex_male            0.076185         -0.011156          0.017117
# smoker_yes          1.000000         -0.036945          0.068498
# region_northwest   -0.036945          1.000000         -0.346265
# region_southeast    0.068498         -0.346265          1.000000
# region_southwest   -0.036945         -0.320829         -0.346265
#
#                   region_southwest
# age                       0.010016
# bmi                      -0.006205
# children                  0.021914
# charges                  -0.043210
# sex_male                 -0.004184
# smoker_yes               -0.036945
# region_northwest         -0.320829
# region_southeast         -0.346265
# region_southwest          1.000000

# %%
#Corelation visualization using Heatmap
cormat = df.corr()
top_corr_features = cormat.index
plt.figure(figsize =(12,12))
g = sns.heatmap(df[top_corr_features].corr(),annot = True,cmap = 'RdYlGn')

# %%
#Dependent Feature
y = df['charges']
y.head()
# Out:
# 0    16884.92400
# 1     1725.55230
# 2     4449.46200
# 3    21984.47061
# 4     3866.85520
# Name: charges, dtype: float64

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>bmi</th>
#       <th>children</th>
#       <th>charges</th>
#       <th>sex_male</th>
#       <th>smoker_yes</th>
#       <th>region_northwest</th>
#       <th>region_southeast</th>
#       <th>region_southwest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>19</td>
#       <td>27.900</td>
#       <td>0</td>
#       <td>16884.92400</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>18</td>
#       <td>33.770</td>
#       <td>1</td>
#       <td>1725.55230</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>28</td>
#       <td>33.000</td>
#       <td>3</td>
#       <td>4449.46200</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>33</td>
#       <td>22.705</td>
#       <td>0</td>
#       <td>21984.47061</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>32</td>
#       <td>28.880</td>
#       <td>0</td>
#       <td>3866.85520</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
x_first_part = df.iloc[0:,0:3]
x_first_part.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>bmi</th>
#       <th>children</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>19</td>
#       <td>27.900</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>18</td>
#       <td>33.770</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>28</td>
#       <td>33.000</td>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>33</td>
#       <td>22.705</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>32</td>
#       <td>28.880</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
x_second_part = df.iloc[0:,4:]
x_second_part.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sex_male</th>
#       <th>smoker_yes</th>
#       <th>region_northwest</th>
#       <th>region_southeast</th>
#       <th>region_southwest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#Indepenedent Feautres
x = x_first_part.join(x_second_part)
x.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>bmi</th>
#       <th>children</th>
#       <th>sex_male</th>
#       <th>smoker_yes</th>
#       <th>region_northwest</th>
#       <th>region_southeast</th>
#       <th>region_southwest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>19</td>
#       <td>27.900</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>18</td>
#       <td>33.770</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>28</td>
#       <td>33.000</td>
#       <td>3</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>33</td>
#       <td>22.705</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>32</td>
#       <td>28.880</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#Dependent Feature
y.head()
# Out:
# 0    16884.92400
# 1     1725.55230
# 2     4449.46200
# 3    21984.47061
# 4     3866.85520
# Name: charges, dtype: float64

# %%
#Feature Importance
from sklearn.ensemble import ExtraTreesRegressor
model = ExtraTreesRegressor()
model.fit(x,y)
# Out:
# ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=None, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=2, min_weight_fraction_leaf=0.0,
#                     n_estimators=100, n_jobs=None, oob_score=False,
#                     random_state=None, verbose=0, warm_start=False)

# %%
#To visualize which feature is important
print(model.feature_importances_)
# Out:
# [0.12968783 0.1916704  0.02362795 0.01015362 0.62059197 0.00919405
#  0.00884764 0.00622654]

# %%
# Visualize more about Important Features
feat_importance = pd.Series(model.feature_importances_,index= x.columns)
feat_importance.nlargest(5).plot(kind='barh')       # Top 5 features
plt.show()

# %%
#Train Test Split
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state = 42)

# %%
x_train.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>bmi</th>
#       <th>children</th>
#       <th>sex_male</th>
#       <th>smoker_yes</th>
#       <th>region_northwest</th>
#       <th>region_southeast</th>
#       <th>region_southwest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>560</th>
#       <td>46</td>
#       <td>19.95</td>
#       <td>2</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1285</th>
#       <td>47</td>
#       <td>24.32</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1142</th>
#       <td>52</td>
#       <td>24.86</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>969</th>
#       <td>39</td>
#       <td>34.32</td>
#       <td>5</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>486</th>
#       <td>54</td>
#       <td>21.47</td>
#       <td>3</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
x_test.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>bmi</th>
#       <th>children</th>
#       <th>sex_male</th>
#       <th>smoker_yes</th>
#       <th>region_northwest</th>
#       <th>region_southeast</th>
#       <th>region_southwest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>764</th>
#       <td>45</td>
#       <td>25.175</td>
#       <td>2</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>887</th>
#       <td>36</td>
#       <td>30.020</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>890</th>
#       <td>64</td>
#       <td>26.885</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1293</th>
#       <td>46</td>
#       <td>25.745</td>
#       <td>3</td>
#       <td>1</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>259</th>
#       <td>19</td>
#       <td>31.920</td>
#       <td>0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
y_train.head()
# Out:
# 560      9193.83850
# 1285     8534.67180
# 1142    27117.99378
# 969      8596.82780
# 486     12475.35130
# Name: charges, dtype: float64

# %%
y_test.head()
# Out:
# 764      9095.06825
# 887      5272.17580
# 890     29330.98315
# 1293     9301.89355
# 259     33750.29180
# Name: charges, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
prediction_lr = lr.predict(x_test)

# %%
sns.distplot(y_test - prediction_lr)

# %%
plt.scatter(y_test,prediction_lr)

# %%
# Train Data Score
print("Train data Score:",lr.score(x_train,y_train))

#Test data Score
print("Test data Score:",lr.score(x_test,y_test))
# Out:
# Train data Score: 0.7417255854683333
# Test data Score: 0.7835929767120723

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(degree = 3)
x_poly = poly.fit_transform(x)

# %%
x_train,x_test,y_train,y_test = train_test_split(x_poly,y, random_state = 42)

# %%
lr_poly = LinearRegression()
lr_poly.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
poly_prediction_lr = lr_poly.predict((x_test))

# %%
sns.distplot(poly_prediction_lr-y_test)

# %%
plt.scatter(poly_prediction_lr, y_test)

# %%
# Train Data Score
print("Train Data Accurace:",lr_poly.score(x_train, y_train))

# Test Data Score
print("Test data Accuracy:",lr_poly.score(x_test, y_test))
# Out:
# Train Data Accurace: 0.857276657162287
# Test data Accuracy: 0.8394269201884316

# %%
y_test.head()
# Out:
# 764      9095.06825
# 887      5272.17580
# 890     29330.98315
# 1293     9301.89355
# 259     33750.29180
# Name: charges, dtype: float64

# %%
print(poly_prediction_lr[:5])
# Out:
# [10565.16870257  5189.51670042 30503.85788173  9902.94310133
#  24212.8474356 ]

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, poly_prediction_lr))
print('MSE:', metrics.mean_squared_error(y_test, poly_prediction_lr))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, poly_prediction_lr)))
# Out:
# MAE: 2965.0862000070733
# MSE: 24229055.018721275
# RMSE: 4922.3018008571225

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=None, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=1,
#                       min_samples_split=2, min_weight_fraction_leaf=0.0,
#                       n_estimators=100, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
rf_predictions = rf.predict(x_test)

# %%
print("Train Data Accurace:",rf.score(x_train,y_train))
print("Test Data Accuracy:",rf.score(x_test,y_test))
# Out:
# Train Data Accurace: 0.9747747612631966
# Test Data Accuracy: 0.8575938047790774

# %%
sns.distplot(rf_predictions-y_test)

# %%
plt.scatter(rf_predictions,y_test)

# %%
from sklearn import metrics
print('MAE:', metrics.mean_absolute_error(y_test, rf_predictions))
print('MSE:', metrics.mean_squared_error(y_test, rf_predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, rf_predictions)))
# Out:
# MAE: 2606.9259445458347
# MSE: 22108381.16461809
# RMSE: 4701.95503643092

# %%
#Hyperparameters Tunning

#Number of tress in one forest
n_estimators = [int(x) for x in np.linspace(10,50, num = 5)]
print(n_estimators)

#Number of features to consider at every split
max_features = ['auto','sqrt']

#Max number of levels in a tree
max_depth = [int(x) for x in np.linspace(1,10,num = 5)]
print(max_depth)

#Minimum number of samples are required to split a node
min_samples_split = [2,3,4,5]

#Minimum number of samples are required at each leaf node
min_samples_leaf = [1,2,3,4]
# Out:
# [10, 20, 30, 40, 50]
# [1, 3, 5, 7, 10]

# %%
#Library to select best parameter values out of the above provided value
from sklearn.model_selection import RandomizedSearchCV

# %%
# Creating the random grid 
random_grid = {'n_estimators': n_estimators,
              'max_features': max_features,
              'max_depth': max_depth,
              'min_samples_split': min_samples_split,
              'min_samples_leaf':min_samples_leaf}
print(random_grid)
# Out:
# {'n_estimators': [10, 20, 30, 40, 50], 'max_features': ['auto', 'sqrt'], 'max_depth': [1, 3, 5, 7, 10], 'min_samples_split': [2, 3, 4, 5], 'min_samples_leaf': [1, 2, 3, 4]}

# %%
#First Creating the base model for tune
rf = RandomForestRegressor()

# %%
rf_random = RandomizedSearchCV(estimator = rf , param_distributions = random_grid,scoring='neg_mean_squared_error',n_iter = 10,cv = 5, verbose = 2,random_state = 0)

# %%
rf_random.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] n_estimators=50, min_samples_split=5, min_samples_leaf=3, max_features=sqrt, max_depth=3
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  n_estimators=50, min_samples_split=5, min_samples_leaf=3, max_features=sqrt, max_depth=3, total=   0.4s
# [CV] n_estimators=50, min_samples_split=5, min_samples_leaf=3, max_features=sqrt, max_depth=3
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.3s remaining:    0.0s
# [CV]  n_estimators=50, min_samples_split=5, min_samples_leaf=3, max_features=sqrt, max_depth=3, total=   0.3s
# [CV] n_estimators=50, min_samples_split=5, min_samples_leaf=3, max_features=sqrt, max_depth=3
# [CV]  n_estimators=50, min_samples_split=5, min_samples_leaf=3, max_features=sqrt, max_depth=3, total=   0.4s
# [CV] n_estimators=50, min_samples_split=5, min_samples_leaf=3, max_features=sqrt, max_depth=3
# [CV]  n_estimators=50, min_samples_split=5, min_samples_leaf=3, max_features=sqrt, max_depth=3, total=   0.4s
# [CV] n_estimators=50, min_samples_split=5, min_samples_leaf=3, max_features=sqrt, max_depth=3
# [CV]  n_estimators=50, min_samples_split=5, min_samples_leaf=3, max_features=sqrt, max_depth=3, total=   0.3s
# [CV] n_estimators=10, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=7
# [CV]  n_estimators=10, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=7, total=   0.1s
# [CV] n_estimators=10, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=7
# [CV]  n_estimators=10, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=7, total=   0.1s
# [CV] n_estimators=10, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=7
# [CV]  n_estimators=10, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=7, total=   0.1s
# [CV] n_estimators=10, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=7
# [CV]  n_estimators=10, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=7, total=   0.1s
# [CV] n_estimators=10, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=7
# [CV]  n_estimators=10, min_samples_split=2, min_samples_leaf=2, max_features=auto, max_depth=7, total=   0.1s
# [CV] n_estimators=40, min_samples_split=2, min_samples_leaf=4, max_features=sqrt, max_depth=3
# [CV]  n_estimators=40, min_samples_split=2, min_samples_leaf=4, max_features=sqrt, max_depth=3, total=   0.3s
# [CV] n_estimators=40, min_samples_split=2, min_samples_leaf=4, max_features=sqrt, max_depth=3
# [CV]  n_estimators=40, min_samples_split=2, min_samples_leaf=4, max_features=sqrt, max_depth=3, total=   0.3s
# [CV] n_estimators=40, min_samples_split=2, min_samples_leaf=4, max_features=sqrt, max_depth=3
# [CV]  n_estimators=40, min_samples_split=2, min_samples_leaf=4, max_features=sqrt, max_depth=3, total=   0.3s
# [CV] n_estimators=40, min_samples_split=2, min_samples_leaf=4, max_features=sqrt, max_depth=3
# [CV]  n_estimators=40, min_samples_split=2, min_samples_leaf=4, max_features=sqrt, max_depth=3, total=   0.3s
# [CV] n_estimators=40, min_samples_split=2, min_samples_leaf=4, max_features=sqrt, max_depth=3
# [CV]  n_estimators=40, min_samples_split=2, min_samples_leaf=4, max_features=sqrt, max_depth=3, total=   0.3s
# [CV] n_estimators=10, min_samples_split=2, min_samples_leaf=3, max_features=auto, max_depth=1
# [CV]  n_estimators=10, min_samples_split=2, min_samples_leaf=3, max_features=auto, max_depth=1, total=   0.1s
# [CV] n_estimators=10, min_samples_split=2, min_samples_leaf=3, max_features=auto, max_depth=1
# [CV]  n_estimators=10, min_samples_split=2, min_samples_leaf=3, max_features=auto, max_depth=1, total=   0.1s
# [CV] n_estimators=10, min_samples_split=2, min_samples_leaf=3, max_features=auto, max_depth=1
# [CV]  n_estimators=10, min_samples_split=2, min_samples_leaf=3, max_features=auto, max_depth=1, total=   0.1s
# [CV] n_estimators=10, min_samples_split=2, min_samples_leaf=3, max_features=auto, max_depth=1
# [CV]  n_estimators=10, min_samples_split=2, min_samples_leaf=3, max_features=auto, max_depth=1, total=   0.1s
# [CV] n_estimators=10, min_samples_split=2, min_samples_leaf=3, max_features=auto, max_depth=1
# [CV]  n_estimators=10, min_samples_split=2, min_samples_leaf=3, max_features=auto, max_depth=1, total=   0.1s
# [CV] n_estimators=10, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=7
# [CV]  n_estimators=10, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=7, total=   0.1s
# [CV] n_estimators=10, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=7
# [CV]  n_estimators=10, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=7, total=   0.1s
# [CV] n_estimators=10, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=7
# [CV]  n_estimators=10, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=7, total=   0.1s
# [CV] n_estimators=10, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=7
# [CV]  n_estimators=10, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=7, total=   0.1s
# [CV] n_estimators=10, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=7
# [CV]  n_estimators=10, min_samples_split=5, min_samples_leaf=1, max_features=auto, max_depth=7, total=   0.1s
# [CV] n_estimators=20, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=20, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   0.2s
# [CV] n_estimators=20, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=20, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   0.2s
# [CV] n_estimators=20, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=20, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   0.2s
# [CV] n_estimators=20, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=20, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   0.2s
# [CV] n_estimators=20, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=5
# [CV]  n_estimators=20, min_samples_split=5, min_samples_leaf=2, max_features=sqrt, max_depth=5, total=   0.2s
# [CV] n_estimators=20, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=3
# [CV]  n_estimators=20, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=3, total=   0.2s
# [CV] n_estimators=20, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=3
# [CV]  n_estimators=20, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=3, total=   0.2s
# [CV] n_estimators=20, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=3
# [CV]  n_estimators=20, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=3, total=   0.1s
# [CV] n_estimators=20, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=3
# [CV]  n_estimators=20, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=3, total=   0.1s
# [CV] n_estimators=20, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=3
# [CV]  n_estimators=20, min_samples_split=5, min_samples_leaf=4, max_features=auto, max_depth=3, total=   0.1s
# [CV] n_estimators=10, min_samples_split=3, min_samples_leaf=3, max_features=sqrt, max_depth=7
# [CV]  n_estimators=10, min_samples_split=3, min_samples_leaf=3, max_features=sqrt, max_depth=7, total=   0.1s
# [CV] n_estimators=10, min_samples_split=3, min_samples_leaf=3, max_features=sqrt, max_depth=7
# [CV]  n_estimators=10, min_samples_split=3, min_samples_leaf=3, max_features=sqrt, max_depth=7, total=   0.1s
# [CV] n_estimators=10, min_samples_split=3, min_samples_leaf=3, max_features=sqrt, max_depth=7
# [CV]  n_estimators=10, min_samples_split=3, min_samples_leaf=3, max_features=sqrt, max_depth=7, total=   0.1s
# [CV] n_estimators=10, min_samples_split=3, min_samples_leaf=3, max_features=sqrt, max_depth=7
# [CV]  n_estimators=10, min_samples_split=3, min_samples_leaf=3, max_features=sqrt, max_depth=7, total=   0.1s
# [CV] n_estimators=10, min_samples_split=3, min_samples_leaf=3, max_features=sqrt, max_depth=7
# [CV]  n_estimators=10, min_samples_split=3, min_samples_leaf=3, max_features=sqrt, max_depth=7, total=   0.1s
# [CV] n_estimators=50, min_samples_split=3, min_samples_leaf=4, max_features=auto, max_depth=5
# [CV]  n_estimators=50, min_samples_split=3, min_samples_leaf=4, max_features=auto, max_depth=5, total=   0.3s
# [CV] n_estimators=50, min_samples_split=3, min_samples_leaf=4, max_features=auto, max_depth=5
# [CV]  n_estimators=50, min_samples_split=3, min_samples_leaf=4, max_features=auto, max_depth=5, total=   0.3s
# [CV] n_estimators=50, min_samples_split=3, min_samples_leaf=4, max_features=auto, max_depth=5
# [CV]  n_estimators=50, min_samples_split=3, min_samples_leaf=4, max_features=auto, max_depth=5, total=   0.3s
# [CV] n_estimators=50, min_samples_split=3, min_samples_leaf=4, max_features=auto, max_depth=5
# [CV]  n_estimators=50, min_samples_split=3, min_samples_leaf=4, max_features=auto, max_depth=5, total=   0.3s
# [CV] n_estimators=50, min_samples_split=3, min_samples_leaf=4, max_features=auto, max_depth=5
# [CV]  n_estimators=50, min_samples_split=3, min_samples_leaf=4, max_features=auto, max_depth=5, total=   0.2s
# [CV] n_estimators=20, min_samples_split=4, min_samples_leaf=4, max_features=auto, max_depth=3
# [CV]  n_estimators=20, min_samples_split=4, min_samples_leaf=4, max_features=auto, max_depth=3, total=   0.1s
# [CV] n_estimators=20, min_samples_split=4, min_samples_leaf=4, max_features=auto, max_depth=3
# [CV]  n_estimators=20, min_samples_split=4, min_samples_leaf=4, max_features=auto, max_depth=3, total=   0.1s
# [CV] n_estimators=20, min_samples_split=4, min_samples_leaf=4, max_features=auto, max_depth=3
# [CV]  n_estimators=20, min_samples_split=4, min_samples_leaf=4, max_features=auto, max_depth=3, total=   0.1s
# [CV] n_estimators=20, min_samples_split=4, min_samples_leaf=4, max_features=auto, max_depth=3
# [CV]  n_estimators=20, min_samples_split=4, min_samples_leaf=4, max_features=auto, max_depth=3, total=   0.1s
# [CV] n_estimators=20, min_samples_split=4, min_samples_leaf=4, max_features=auto, max_depth=3
# [CV]  n_estimators=20, min_samples_split=4, min_samples_leaf=4, max_features=auto, max_depth=3, total=   0.1s
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:    8.9s finished
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=RandomForestRegressor(bootstrap=True,
#                                                    ccp_alpha=0.0,
#                                                    criterion='mse',
#                                                    max_depth=None,
#                                                    max_features='auto',
#                                                    max_leaf_nodes=None,
#                                                    max_samples=None,
#                                                    min_impurity_decrease=0.0,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=1,
#                                                    min_samples_split=2,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    n_estimators=100,
#                                                    n_jobs=None, oob_score=False,
#                                                    random_state=None, verbose=0,
#                                                    warm_start=False),
#                    iid='deprecated', n_iter=10, n_jobs=None,
#                    param_distributions={'max_depth': [1, 3, 5, 7, 10],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 3, 4],
#                                         'min_samples_split': [2, 3, 4, 5],
#                                         'n_estimators': [10, 20, 30, 40, 50]},
#                    pre_dispatch='2*n_jobs', random_state=0, refit=True,
#                    return_train_score=False, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
rf_random.best_estimator_
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=3, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=4,
#                       min_samples_split=5, min_weight_fraction_leaf=0.0,
#                       n_estimators=20, n_jobs=None, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
#best parameters for this model
rf_random.best_params_
# Out:
# {'n_estimators': 20,
#  'min_samples_split': 5,
#  'min_samples_leaf': 4,
#  'max_features': 'auto',
#  'max_depth': 3}

# %%
rf = RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=5,
           max_features='auto', max_leaf_nodes=None,
           min_impurity_decrease=0.0, min_impurity_split=None,
           min_samples_leaf=4, min_samples_split=3,
           min_weight_fraction_leaf=0.0, n_estimators=50, n_jobs=1,
           oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mse',
#                       max_depth=5, max_features='auto', max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0,
#                       min_impurity_split=None, min_samples_leaf=4,
#                       min_samples_split=3, min_weight_fraction_leaf=0.0,
#                       n_estimators=50, n_jobs=1, oob_score=False,
#                       random_state=None, verbose=0, warm_start=False)

# %%
prediction = rf.predict(x_test)

# %%
sns.distplot(y_test-prediction)

# %%
plt.scatter(y_test,prediction)

# %%
print("Train Data Accurace:",rf.score(x_train,y_train))
print("Test Data Accuracy:",rf.score(x_test,y_test))
# Out:
# Train Data Accurace: 0.8813082710394772
# Test Data Accuracy: 0.8762853698403792

# %%
plt.figure(figsize =(20,10))
x_ax = range(len(y_test))
plt.plot(x_ax, y_test, label="original")
plt.plot(x_ax, prediction, label="predicted")
plt.title("Test and predicted data")
plt.legend()
plt.show()

# %%
from sklearn.model_selection import cross_val_score

# %%
score = cross_val_score(rf, x_train,y_train,cv=10)
score
# Out:
# array([0.88553636, 0.83697066, 0.9501974 , 0.86491602, 0.79092304,
#        0.86204959, 0.74780249, 0.80929678, 0.85535425, 0.86127279])

# %%
score.mean()
# Out:
# 0.8464319368879917

# %%
score = cross_val_score(rf, x_test,y_test,cv=10)
score
# Out:
# array([0.9518857 , 0.71937971, 0.94638305, 0.63451611, 0.92252397,
#        0.78841004, 0.82113967, 0.87545097, 0.86430361, 0.77845347])

# %%
score.mean()
# Out:
# 0.8302446298672468

# %% [markdown]
# ### Applying Cross Validation on Full dataset

# %%
score = cross_val_score(rf, x,y,cv=10)
score
# Out:
# array([0.89533348, 0.86727651, 0.84319403, 0.753348  , 0.86817553,
#        0.92606086, 0.87684458, 0.81552442, 0.870379  , 0.8678438 ])

# %%
score.mean()
# Out:
# 0.8583980206372968

# %%
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import r2_score
predictions = cross_val_predict(rf, x_test, y_test, cv=10)
print("R2 Score:", r2_score(y_test,predictions))
# Out:
# R2 Score: 0.8645759203093426

# %%
import xgboost

# %%
xgb = xgboost.XGBRegressor()

# %%
xgb.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=0, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
prediction = xgb.predict(x_test)

# %%
sns.distplot(y_test-prediction)

# %%
plt.scatter(y_test,prediction)

# %%
print("Train Data Accurace:",xgb.score(x_train,y_train))
print("Test Data Accuracy:",xgb.score(x_test,y_test))
# Out:
# Train Data Accurace: 0.9974240796500188
# Test Data Accuracy: 0.8369874843574545

# %%
#Hyperparameters Tunning
n_estimators=[80,100,150,200,250,300]
gamma= [0.0,0.1,0.2,0.3,0.4]
learning_rate= [0.25,0.30,0.35,0.4,0.5]
min_child_weight=[1,3,5,7]
max_depth=[4,6,8,10,12,15]
colsample_bynode=[1,1.5,2,3]

# %%
param_grid = {'n_estimators':n_estimators, 'gamma': gamma, 'learning_rate': learning_rate, 'min_child_weight': min_child_weight,             
              'max_depth': max_depth, 'colsample_bynode': colsample_bynode }
print(param_grid)
# Out:
# {'n_estimators': [80, 100, 150, 200, 250, 300], 'gamma': [0.0, 0.1, 0.2, 0.3, 0.4], 'learning_rate': [0.25, 0.3, 0.35, 0.4, 0.5], 'min_child_weight': [1, 3, 5, 7], 'max_depth': [4, 6, 8, 10, 12, 15], 'colsample_bynode': [1, 1.5, 2, 3]}

# %%
xgb = xgboost.XGBRegressor()

# %%
xgb_random = RandomizedSearchCV(estimator = xgb , param_distributions = param_grid,scoring='neg_mean_squared_error',n_iter = 10,cv = 5, verbose = 1,random_state = 0)
xgb_random.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Program Files\Anaconda\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# xgboost.core.XGBoostError: value 2 for Parameter colsample_bynode exceed bound [0,1]
# colsample_bynode: Subsample ratio of columns, resample on each node (split).
#
#   FitFailedWarning)
# C:\Program Files\Anaconda\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# xgboost.core.XGBoostError: value 3 for Parameter colsample_bynode exceed bound [0,1]
# colsample_bynode: Subsample ratio of columns, resample on each node (split).
#
#   FitFailedWarning)
# C:\Program Files\Anaconda\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# xgboost.core.XGBoostError: value 1.5 for Parameter colsample_bynode exceed bound [0,1]
# colsample_bynode: Subsample ratio of columns, resample on each node (split).
#
#   FitFailedWarning)
# C:\Program Files\Anaconda\lib\site-packages\sklearn\model_selection\_validation.py:536: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# xgboost.core.XGBoostError: value 2 for Parameter colsample_bynode exceed bound [0,1]
# colsample_bynode: Subsample ratio of columns, resample on each node (split).
#
#   FitFailedWarning)
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:   22.1s finished
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None, gamma=None,
#                                           gpu_id=None, importance_type='gain',
#                                           interaction_constraints=None,
#                                           learning_rate=None,
#                                           max_delta_step=None, max_depth=None,
#                                           min_child_weight=None, missing=nan,
#                                           monotone_constraints=None,
#                                           n_...
#                    iid='deprecated', n_iter=10, n_jobs=None,
#                    param_distributions={'colsample_bynode': [1, 1.5, 2, 3],
#                                         'gamma': [0.0, 0.1, 0.2, 0.3, 0.4],
#                                         'learning_rate': [0.25, 0.3, 0.35, 0.4,
#                                                           0.5],
#                                         'max_depth': [4, 6, 8, 10, 12, 15],
#                                         'min_child_weight': [1, 3, 5, 7],
#                                         'n_estimators': [80, 100, 150, 200, 250,
#                                                          300]},
#                    pre_dispatch='2*n_jobs', random_state=0, refit=True,
#                    return_train_score=False, scoring='neg_mean_squared_error',
#                    verbose=1)

# %%
xgb_random.best_params_
# Out:
# {'n_estimators': 80,
#  'min_child_weight': 1,
#  'max_depth': 12,
#  'learning_rate': 0.35,
#  'gamma': 0.4,
#  'colsample_bynode': 1}

# %%
xgb_random.best_estimator_
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0.4, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.35, max_delta_step=0, max_depth=12,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=80, n_jobs=0, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
xgb_tuned = xgboost.XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
             colsample_bynode=1, colsample_bytree=1, gamma=0.4, gpu_id=-1,
             importance_type='gain', interaction_constraints='',
             learning_rate=0.35, max_delta_step=0, max_depth=12,
             min_child_weight=1,monotone_constraints='()',
             n_estimators=80, n_jobs=0, num_parallel_tree=1,
             objective='reg:squarederror', random_state=0, reg_alpha=0,
             reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
             validate_parameters=1, verbosity=None)

# %%
xgb_tuned.fit(x_train,y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0.4, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.35, max_delta_step=0, max_depth=12,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=80, n_jobs=0, num_parallel_tree=1,
#              objective='reg:squarederror', random_state=0, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='exact',
#              validate_parameters=1, verbosity=None)

# %%
prediction = xgb_tuned.predict(x_test)

# %%
print("Train Data Accurace:",xgb_tuned.score(x_train,y_train))
print("Test Data Accuracy:",xgb_tuned.score(x_test,y_test))
# Out:
# Train Data Accurace: 0.998741099583929
# Test Data Accuracy: 0.8313109001236038

# %%
import pickle

# open a file, where you ant to store the data
file = open('RanodmForest_Regression_model.pkl','wb')

# dump information to that file
pickle.dump(rf,file)

# %%
from platform import python_version

print(python_version())
# Out:
# 3.7.6
